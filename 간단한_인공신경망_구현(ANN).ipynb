# %% [markdown]
# <a href="https://colab.research.google.com/github/yiseeun/yiseeun/blob/main/%EA%B0%84%EB%8B%A8%ED%95%9C_%EC%9D%B8%EA%B3%B5%EC%8B%A0%EA%B2%BD%EB%A7%9D_%EA%B5%AC%ED%98%84(ANN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt


targetUrl = "https://raw.githubusercontent.com/gundaminpde/2022/main/sonar3.csv"


Data_set = pd.read_csv(targetUrl, sep=',')


print(Data_set.shape)
Data_set.head()
# Out:
# (207, 61)
#      0.02  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167   0.018  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#     0.009  0.0032  0
# 0  0.0052  0.0044  0
# 1  0.0095  0.0078  0
# ...

# %%
X = Data_set.iloc[:,0:60]
y = Data_set.iloc[:,60]

# %%
X.head()
# Out:
#      0.02  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0232  0.0027  0.0065  0.0159  0.0072  0.0167   0.018  \
# 0  0.2872  ...  0.0125  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140
# 1  0.6194  ...  0.0033  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316
# 2  0.1264  ...  0.0241  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050
# 3  0.4459  ...  0.0156  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072
# 4  0.3039  ...  0.0104  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057
#
#    0.0084   0.009  0.0032
# 0  0.0049  0.0052  0.0044
# 1  0.0164  0.0095  0.0078
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: 0, dtype: int64

# %%
model = Sequential()
model.add(Dense(30, input_dim=60, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])
history=model.fit(X, y, epochs=100, batch_size=5)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 1s 2ms/step - loss: 0.6964 - binary_accuracy: 0.5362
# Epoch 2/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6783 - binary_accuracy: 0.5411
# Epoch 3/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6652 - binary_accuracy: 0.5749
# Epoch 4/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6571 - binary_accuracy: 0.5700
# Epoch 5/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6536 - binary_accuracy: 0.6812
# Epoch 6/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6356 - binary_accuracy: 0.6522
# Epoch 7/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6199 - binary_accuracy: 0.6763
# Epoch 8/100
# 42/42 [==============================] - 0s 2ms/step - loss: 0.6058 - binary_accuracy: 0.7150
# Epoch 9/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.5893 - binary_accuracy: 0.7150
# ...
